# %% [markdown]
# # NIDS Research Experiments (Colab)

# %%
# !pip install -r requirements.txt --quiet

# %%
# !python src/preprocess_cicids2017.py

# %%
# !python src/baseline_run.py

# %%
# !python src/improved_run.py

# %%
# !python src/plot_roc.py
